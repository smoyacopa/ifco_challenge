# %%
# %sh
cd /Workspace/IFCO_Challenge

# TESTS 01
# Le inyectamos la ruta absoluta al PYTHONPATH para que encuentre 'src'
export PYTHONPATH="/Workspace/IFCO_Challenge"

# Ejecutamos apagando los bytes y moviendo la caché a /tmp
PYTHONDONTWRITEBYTECODE=1 pytest tests/test_01.py -v -o cache_dir=/tmp/.pytest_cache
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-8.3.5, pluggy-1.5.0 -- /databricks/python3/bin/python
# cachedir: /tmp/.pytest_cache
# rootdir: /Workspace/IFCO_Challenge
# plugins: langsmith-0.6.1, anyio-4.7.0
# collecting ... collected 4 items
#
# tests/test_01.py::test_elimina_puntos PASSED                             [ 25%]
# tests/test_01.py::test_dos_variantes_dan_mismo_resultado PASSED          [ 50%]
# tests/test_01.py::test_nombre_vacio PASSED                               [ 75%]
# tests/test_01.py::test_none_devuelve_vacio PASSED                        [100%]
#
# ============================== 4 passed in 0.29s ===============================

# %%
# %sh
cd /Workspace/IFCO_Challenge

# TESTS 02
export PYTHONPATH="/Workspace/IFCO_Challenge"

PYTHONDONTWRITEBYTECODE=1 pytest tests/test_02.py -v -o cache_dir=/tmp/.pytest_cache
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-8.3.5, pluggy-1.5.0 -- /databricks/python3/bin/python
# cachedir: /tmp/.pytest_cache
# rootdir: /Workspace/IFCO_Challenge
# plugins: langsmith-0.6.1, anyio-4.7.0
# collecting ... collected 8 items
#
# tests/test_02.py::TestGetFullName::test_nombre_y_apellido_completos PASSED [ 12%]
# tests/test_02.py::TestGetFullName::test_solo_nombre_sin_apellido PASSED  [ 25%]
# tests/test_02.py::TestGetFullName::test_solo_apellido_sin_nombre PASSED  [ 37%]
# tests/test_02.py::TestGetFullName::test_vacio_devuelve_placeholder PASSED [ 50%]
# tests/test_02.py::TestGetFullName::test_none_devuelve_placeholder PASSED [ 62%]
# tests/test_02.py::TestGetFullName::test_json_malformado_devuelve_placeholder PASSED [ 75%]
# tests/test_02.py::TestGetFullName::test_campos_vacios_devuelve_placeholder PASSED [ 87%]
# ...

# %%
# %sh
cd /Workspace/IFCO_Challenge

# TESTS 03
export PYTHONPATH="/Workspace/IFCO_Challenge"

PYTHONDONTWRITEBYTECODE=1 pytest tests/test_03.py -v -o cache_dir=/tmp/.pytest_cache
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-8.3.5, pluggy-1.5.0 -- /databricks/python3/bin/python
# cachedir: /tmp/.pytest_cache
# rootdir: /Workspace/IFCO_Challenge
# plugins: langsmith-0.6.1, anyio-4.7.0
# collecting ... collected 10 items
#
# tests/test_03.py::TestGetAddress::test_ciudad_y_cp_completos PASSED      [ 10%]
# tests/test_03.py::TestGetAddress::test_cp_como_entero PASSED             [ 20%]
# tests/test_03.py::TestGetAddress::test_ciudad_ausente_usa_placeholder PASSED [ 30%]
# tests/test_03.py::TestGetAddress::test_cp_ausente_usa_placeholder PASSED [ 40%]
# tests/test_03.py::TestGetAddress::test_ambos_ausentes_doble_placeholder PASSED [ 50%]
# tests/test_03.py::TestGetAddress::test_vacio_doble_placeholder PASSED    [ 60%]
# tests/test_03.py::TestGetAddress::test_none_doble_placeholder PASSED     [ 70%]
# tests/test_03.py::TestGetAddress::test_json_malformado_doble_placeholder PASSED [ 80%]
# ...

# %%
# %sh
cd /Workspace/IFCO_Challenge

# TESTS 04
export PYTHONPATH="/Workspace/IFCO_Challenge"

PYTHONDONTWRITEBYTECODE=1 pytest tests/test_04.py -v -o cache_dir=/tmp/.pytest_cache
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-8.3.5, pluggy-1.5.0 -- /databricks/python3/bin/python
# cachedir: /tmp/.pytest_cache
# rootdir: /Workspace/IFCO_Challenge
# plugins: langsmith-0.6.1, anyio-4.7.0
# collecting ... collected 11 items
#
# tests/test_04.py::TestCalculateNetValue::test_sin_iva PASSED             [  9%]
# tests/test_04.py::TestCalculateNetValue::test_con_iva_19 PASSED          [ 18%]
# tests/test_04.py::TestCalculateNetValue::test_con_iva_21 PASSED          [ 27%]
# tests/test_04.py::TestCalculateNetValue::test_con_iva_34 PASSED          [ 36%]
# tests/test_04.py::TestCalculateNetValue::test_gross_none_devuelve_cero PASSED [ 45%]
# tests/test_04.py::TestCalculateNetValue::test_vat_none_devuelve_cero PASSED [ 54%]
# tests/test_04.py::TestGetCommissionRate::test_main_owner_6_pct PASSED    [ 63%]
# tests/test_04.py::TestGetCommissionRate::test_coowner1_2_5_pct PASSED    [ 72%]
# ...

# %%
# %sh
cd /Workspace/IFCO_Challenge

# TESTS 05
export PYTHONPATH="/Workspace/IFCO_Challenge"

PYTHONDONTWRITEBYTECODE=1 pytest tests/test_05.py -v -o cache_dir=/tmp/.pytest_cache
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-8.3.5, pluggy-1.5.0 -- /databricks/python3/bin/python
# cachedir: /tmp/.pytest_cache
# rootdir: /Workspace/IFCO_Challenge
# plugins: langsmith-0.6.1, anyio-4.7.0
# collecting ... collected 7 items
#
# tests/test_05.py::TestNormalizeCompanyName::test_elimina_puntos PASSED   [ 14%]
# tests/test_05.py::TestNormalizeCompanyName::test_elimina_mayusculas PASSED [ 28%]
# tests/test_05.py::TestNormalizeCompanyName::test_elimina_caracteres_especiales PASSED [ 42%]
# tests/test_05.py::TestNormalizeCompanyName::test_trim_espacios PASSED    [ 57%]
# tests/test_05.py::TestNormalizeCompanyName::test_string_vacio PASSED     [ 71%]
# tests/test_05.py::TestNormalizeCompanyName::test_none_devuelve_vacio PASSED [ 85%]
# tests/test_05.py::TestNormalizeCompanyName::test_fresh_fruits_variantes_dan_mismo_resultado PASSED [100%]
#
# ...
